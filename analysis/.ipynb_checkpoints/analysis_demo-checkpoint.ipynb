# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_aggressive = pd.read_csv("data/aggressive.csv")
df_aggressive = df_aggressive.dropna()
for name, group in df_aggressive.groupby("trader"):
    plt.plot(group["round"],group["threshold"],label=name)
    plt.title("Aggressive Strategy")
    plt.legend()

# %%
df_passive = pd.read_csv("data/passive.csv")
df_passive = df_passive.dropna()
for name, group in df_passive.groupby("trader"):
    plt.plot(group["round"],group["threshold"],label=name)
    plt.title("Passive Strategy")
    plt.legend()
